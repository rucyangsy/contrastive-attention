# %%
import json
import matplotlib.pyplot as plt

# %%
size = 2

# %% [markdown]
# # pacman

# %%
size=3
#pacman baseline 1
path_pac_1 = '../baseline_log/log/MsPacmanNoFrameskip-v4/a2c/a2c_mspacman_seed_1_2023-04-02-16-57/all_scalars.json'
with open(path_pac_1, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_pac_1, y_pac_1 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % size == 0 :
        y_pac_1.append(scores/size)
        x_pac_1.append(steps)
        scores = 0
    i += 1

# %%
#pacman baseline 2
path_pac_2 = '../baseline_log/log/MsPacmanNoFrameskip-v4/a2c/a2c_mspacman_seed_2_2023-04-03-03-08/all_scalars.json'
with open(path_pac_2, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_pac_2, y_pac_2 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % size == 0 :
        y_pac_2.append(scores/size)
        x_pac_2.append(steps)
        scores = 0
    i += 1

# %%
# pacman attention 2
path_pac_at_2 = './log/MsPacmanNoFrameskip-v4/a2c/aug34256_seed_2_2023-04-05-03-34/all_scalars.json'
with open(path_pac_at_2, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_pac_at_2, y_pac_at_2 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % 2 == 0 :
        y_pac_at_2.append(scores/2)
        x_pac_at_2.append(steps)
        scores = 0
    i += 1

# %%
./log/MsPacmanNoFrameskip-v4/a2c/ms_top_down_seed_1_2023-04-06-03-58/all_scalars.json

# %%
# pacman top-down attention 1
path_pac_top_1 = './log/MsPacmanNoFrameskip-v4/a2c/ms_top_down_seed_1_2023-04-06-03-58/all_scalars.json'
with open(path_pac_top_1, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_pac_top_1, y_pac_top_1 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % 2 == 0 :
        y_pac_top_1.append(scores/2)
        x_pac_top_1.append(steps)
        scores = 0
    i += 1

# %%
# pacman top-down attention 2
path_pac_top_2 = './log/MsPacmanNoFrameskip-v4/a2c/ms_top_down_seed_2_2023-04-05-19-02/all_scalars.json'
with open(path_pac_top_2, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_pac_top_2, y_pac_top_2 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % 2 == 0 :
        y_pac_top_2.append(scores/2)
        x_pac_top_2.append(steps)
        scores = 0
    i += 1

# %%
#pac_multnival baseline 2
path_pac_mult_1 = './log/MsPacmanNoFrameskip-v4/a2c/ms_top_down_seed_2_2023-04-05-19-02/all_scalars.json'
with open(path_pac_mult_1, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_pac_mult_1, y_pac_mult_1 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % 4 == 0 :
        y_pac_mult_1.append(scores/4)
        x_pac_mult_1.append(steps)
        scores = 0
    i += 1

# %%
/log/MsPacmanNoFrameskip-v4/a2c/ms_from_car_seed_2_2023-04-08-13-15/all_scalars.json

# %%
size=3
# pacman trans from carnival 
path_pac_trans_1 = './log/MsPacmanNoFrameskip-v4/a2c/ms_from_car_seed_1_2023-04-08-18-21/all_scalars.json'
with open(path_pac_trans_1, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_pac_trans_1, y_pac_trans_1 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % size == 0 :
        y_pac_trans_1.append(scores/size)
        x_pac_trans_1.append(steps)
        scores = 0
    i += 1 
# pacnival trans from pacman 
path_pac_trans_2 = './log/MsPacmanNoFrameskip-v4/a2c/ms_from_car_seed_2_2023-04-08-13-15/all_scalars.json'
with open(path_pac_trans_2, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_pac_trans_2, y_pac_trans_2 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % size == 0 :
        y_pac_trans_2.append(scores/size)
        x_pac_trans_2.append(steps)
        scores = 0
    i += 1 
path_pac_trans_3 = './log/MsPacmanNoFrameskip-v4/a2c/ms_from_car_seed_3_2023-04-08-18-21/all_scalars.json'
with open(path_pac_trans_3, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_pac_trans_3, y_pac_trans_3 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % size == 0 :
        y_pac_trans_3.append(scores/size)
        x_pac_trans_3.append(steps)
        scores = 0
    i += 1

# %%
x_pac_base, y_pac_base = x_pac_1, [(y_pac_1[i] + y_pac_2[i])/2 for i in range(len(x_pac_1))]
x_pac_top, y_pac_top = x_pac_trans_1, [( y_pac_trans_1[i] +  y_pac_trans_2[i] + y_pac_trans_3[i])/3 for i in range(len( y_pac_trans_1))]
x_pac_trans, y_pac_trans = x_pac_top_1, [( y_pac_top_1[i] +  y_pac_top_2[i])/2 for i in range(len( y_pac_top_1))]
plt.plot(x_pac_base, y_pac_base, label = "a2c")
plt.plot(x_pac_at_2, y_pac_at_2, label = "a2c w/ our attention")
#plt.plot(x_pac_top, y_pac_top, label = "a2c w/ top-down attention")
#plt.plot(x_pac_mult_1, y_pac_mult_1, label = "a2c w/ univ.attention")
plt.plot(x_pac_trans, y_pac_trans, label = "a2c w/ fix att. from Carnival")
plt.xlabel('num of steps',fontsize=16)
plt.ylabel('test scores',fontsize=16)
plt.title('Ms Pacman',fontsize=16)
plt.legend(fontsize=12)
plt.show()

# %% [markdown]
# # Carnival

# %%
#carnival baseline 1
path_car_1 = '../baseline_log/log/CarnivalNoFrameskip-v4/a2c/carnival_seed_1_2023-04-02-16-58/all_scalars.json'
with open(path_car_1, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_car_1, y_car_1 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % 2 == 0 :
        y_car_1.append(scores/2)
        x_car_1.append(steps)
        scores = 0
    i += 1

# %%
#carnival baseline 1
path_car_2 = '../baseline_log/log/CarnivalNoFrameskip-v4/a2c/carnival_seed_2_2023-04-03-03-08/all_scalars.json'
with open(path_car_2, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_car_2, y_car_2 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % 2 == 0 :
        y_car_2.append(scores/2)
        x_car_2.append(steps)
        scores = 0
    i += 1

# %%
   #carnival attention 2
path_car_at_2 = './log/CarnivalNoFrameskip-v4/a2c/carnival_seed_2_2023-04-05-19-02/all_scalars.json'
with open(path_car_at_2, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_car_at_2, y_car_at_2 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % 2 == 0 :
        y_car_at_2.append(scores/2)
        x_car_at_2.append(steps)
        scores = 0
    i += 1

# %%
./log/CarnivalNoFrameskip-v4/a2c/car_top_down_seed_1_2023-04-06-11-07/all_scalars.json

# %%
 #carman top-down attention 1
path_car_top_1 = './log/CarnivalNoFrameskip-v4/a2c/car_top_down_seed_1_2023-04-06-11-07/all_scalars.json'
with open(path_car_top_1, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_car_top_1, y_car_top_1 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % 2 == 0 :
        y_car_top_1.append(scores/2)
        x_car_top_1.append(steps)
        scores = 0
    i += 1 
# carman top-down attention 2
path_car_top_2 = './log/CarnivalNoFrameskip-v4/a2c/car_top_down_seed_2_2023-04-06-03-54/all_scalars.json'
with open(path_car_top_2, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_car_top_2, y_car_top_2 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % 2 == 0 :
        y_car_top_2.append(scores/2)
        x_car_top_2.append(steps)
        scores = 0
    i += 1

# %%
/log/CarnivalNoFrameskip-v4/a2c/car_multi_seed_2_2023-04-08-13-02/all_scalars.json

# %%
#car_multnival baseline 2
path_car_mult_1 = './log/CarnivalNoFrameskip-v4/a2c/car_multi_seed_2_2023-04-08-13-02/all_scalars.json'
with open(path_car_mult_1, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_car_mult_1, y_car_mult_1 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % 2 == 0 :
        y_car_mult_1.append(scores/2)
        x_car_mult_1.append(steps)
        scores = 0
    i += 1

# %%
/yangsy/DM-homework/log/CarnivalNoFrameskip-v4/a2c/car_trans_seed_2_2023-04-07-23-23/all_scalars.json

# %%
# carnival trans from pacman 
path_car_trans_2 = './log/CarnivalNoFrameskip-v4/a2c/car_trans_seed_2_2023-04-07-23-23/all_scalars.json'
with open(path_car_trans_2, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_car_trans_2, y_car_trans_2 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % 2 == 0 :
        y_car_trans_2.append(scores/2)
        x_car_trans_2.append(steps)
        scores = 0
    i += 1

# %%
x_car_base, y_car_base = x_car_1, [(y_car_1[i] + y_car_2[i])/2 for i in range(len(y_car_1))]
x_car_top, y_car_top = x_car_top_1, [(y_car_top_1[i] + y_car_top_2[i])/2 for i in range(len(y_car_top_1))]
plt.plot(x_car_base, y_car_base, label = "a2c")
plt.plot(x_car_at_2, y_car_at_2, label = "a2c w/ our attention")
#plt.plot(x_car_top, y_car_top, label = "a2c w/ top-down attention")
#plt.plot(x_car_trans_2, y_car_trans_2, label = "trans ttention")
plt.plot(x_car_mult_1, y_car_mult_1, label = "a2c w/ univ.attention")
plt.xlabel('num of steps',fontsize=16)
plt.ylabel('test scores',fontsize=16)
plt.title('Carnival',fontsize=16)
plt.legend(fontsize=12)
plt.show()

# %% [markdown]
# # freeway

# %%
#freeway baseline 1
path_fre_1 = '../baseline_log/log/FreewayNoFrameskip-v4/a2c/freeway_seed_1_2023-04-02-16-59/all_scalars.json'

with open(path_fre_1, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_fre_1, y_fre_1 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % size == 0 :
        y_fre_1.append(scores/size)
        x_fre_1.append(steps)
        scores = 0
    i += 1

# %%
#freeway baseline 2
path_fre_2 = '../baseline_log/log/FreewayNoFrameskip-v4/a2c/freeway_seed_2_2023-04-03-03-09/all_scalars.json'
with open(path_fre_1, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_fre_2, y_fre_2 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % size == 0 :
        y_fre_2.append(scores/size)
        x_fre_2.append(steps)
        scores = 0
    i += 1

# %%
# freman top-down attention 2
path_fre_top_2 = './log/FreewayNoFrameskip-v4/a2c/fre_top_down_seed_1_2023-04-06-11-07/all_scalars.json'
with open(path_fre_top_2, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_fre_top_2, y_fre_top_2 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % 2 == 0 :
        y_fre_top_2.append(scores/2)
        x_fre_top_2.append(steps)
        scores = 0
    i += 1

# %%
#fre_ateway att 2
path_fre_at_2 = './log/FreewayNoFrameskip-v4/a2c/freeway_seed_2_2023-04-05-19-01/all_scalars.json'
with open(path_fre_at_2, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_fre_at_2, y_fre_at_2 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % size == 0 :
        y_fre_at_2.append(scores/size)
        x_fre_at_2.append(steps)
        scores = 0
    i += 1

# %%
x_fre_base, y_fre_base = x_fre_1, [(y_fre_1[i] + y_fre_2[i])/2 for i in range(len(y_fre_1))]
#plt.plot(x_fre_base, y_fre_base, label = "a2c")
plt.plot(x_fre_at_2, y_fre_at_2, label = "a2c w/ our attention")
plt.plot(x_fre_top_2, y_fre_top_2, label = "a2c w/ top-down attention")
plt.xlabel('num of steps')
plt.ylabel('test scores')
plt.title('Freeway')
plt.legend()
plt.show()

# %% [markdown]
# # assault

# %%
#ass baseline 1
path_ass_1 = '../baseline_log/log/AssaultNoFrameskip-v4/a2c/Assault_seed_1_2023-04-03-16-38/all_scalars.json'
with open(path_ass_1, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_ass_1, y_ass_1 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % 2 == 0 :
        y_ass_1.append(scores/2)
        x_ass_1.append(steps)
        scores = 0
    i += 1  
 #ass baseline 2
path_ass_2 = '../baseline_log/log/AssaultNoFrameskip-v4/a2c/Assault_seed_2_2023-04-04-08-37/all_scalars.json'
with open(path_ass_1, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_ass_2, y_ass_2 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % 2 == 0 :
        y_ass_2.append(scores/2)
        x_ass_2.append(steps)
        scores = 0
    i += 1

# %%
#ass_attention att 2
path_ass_at_2 = './log/AssaultNoFrameskip-v4/a2c/assault_seed_2_2023-04-05-18-59/all_scalars.json'
with open(path_ass_at_2, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_ass_at_2, y_ass_at_2 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % size == 0 :
        y_ass_at_2.append(scores/size)
        x_ass_at_2.append(steps)
        scores = 0
    i += 1

# %%
/log/AssaultNoFrameskip-v4/a2c/assault_seed_2_2023-04-08-00-43/all_scalars.json

# %%
#ass_attention att 2
path_ass_at_2 = './log/AssaultNoFrameskip-v4/a2c/assault_seed_2_2023-04-08-00-43/all_scalars.json'
with open(path_ass_at_2, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_ass_at_2, y_ass_at_2 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % size == 0 :
        y_ass_at_2.append(scores/size)
        x_ass_at_2.append(steps)
        scores = 0
    i += 1

# %%
# assman top-down attention 2
path_ass_top_2 = './log/AssaultNoFrameskip-v4/a2c/ass_top_down_seed_2_2023-04-06-11-12/all_scalars.json'
with open(path_ass_top_2, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_ass_top_2, y_ass_top_2 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % 2 == 0 :
        y_ass_top_2.append(scores/2)
        x_ass_top_2.append(steps)
        scores = 0
    i += 1

# %%
#ass_self att 2
path_ass_self_2 = '../baseline_log/log/AssaultNoFrameskip-v4/a2c/Assault_self_seed_1_2023-04-03-16-38/all_scalars.json'
with open(path_ass_self_2, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_ass_self_2, y_ass_self_2 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % size == 0 :
        y_ass_self_2.append(scores/size)
        x_ass_self_2.append(steps)
        scores = 0
    i += 1

# %%
#ass_multeway att 2
path_ass_mult_2 = './log/AssaultNoFrameskip-v4/a2c/ass_multi_seed_2_2023-04-06-15-07/all_scalars.json'
with open(path_ass_mult_2, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_ass_mult_2, y_ass_mult_2 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % size == 0 :
        y_ass_mult_2.append(scores/size)
        x_ass_mult_2.append(steps)
        scores = 0
    i += 1

# %%
x_ass_base, y_ass_base = x_ass_1, [(y_ass_1[i] + y_ass_2[i])/2 for i in range(len(y_ass_1))]
plt.plot(x_ass_base, y_ass_base, label = "a2c")
plt.plot(x_ass_at_2, y_ass_at_2, label = "a2c w/ our attention")
plt.plot(x_ass_top_2, y_ass_top_2, label = "a2c w/ top-down attention")
#plt.plot(x_ass_self_2, y_ass_self_2, label = "a2c w/self-attention")
#plt.plot(x_ass_mult_2, y_ass_mult_2, label = "a2c w/univ.attention")
plt.xlabel('num of steps')
plt.ylabel('test scores')
plt.title('Assault')
plt.legend()
plt.show()

# %% [markdown]
# # asteroids

# %%
#ast baseline 1

path_ast_1 = '../baseline_log/log/AsteroidsNoFrameskip-v4/a2c/asteroids_seed_1_2023-04-02-17-00/all_scalars.json'
with open(path_ast_1, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_ast_1, y_ast_1 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % 2 == 0 :
        y_ast_1.append(scores/2)
        x_ast_1.append(steps)
        scores = 0
    i += 1  
 #ast baseline 2
path_ast_2 = '../baseline_log/log/AsteroidsNoFrameskip-v4/a2c/asteroids_seed_2_2023-04-03-03-09/all_scalars.json'
with open(path_ast_2, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_ast_2, y_ast_2 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % 2 == 0 :
        y_ast_2.append(scores/2)
        x_ast_2.append(steps)
        scores = 0
    i += 1

# %%
./log/AsteroidsNoFrameskip-v4/a2c/asteroids_seed_2_2023-04-05-19-00/all_scalars.json

# %%
#ast_ateway att 2
size=3
path_ast_at_2 = './log/AsteroidsNoFrameskip-v4/a2c/asteroids_seed_2_2023-04-05-19-00/all_scalars.json'
with open(path_ast_at_2, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_ast_at_2, y_ast_at_2 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % size == 0 :
        y_ast_at_2.append(scores/size)
        x_ast_at_2.append(steps)
        scores = 0
    i += 1

# %%
size=2
# ast top-down attention 1
path_ast_top_1 = './log/AsteroidsNoFrameskip-v4/a2c/ast_top_down_seed_1_2023-04-06-11-07/all_scalars.json'
with open(path_ast_top_1, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_ast_top_1, y_ast_top_1 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % size == 0 :
        y_ast_top_1.append(scores/size)
        x_ast_top_1.append(steps)
        scores = 0
    i += 1 
    #ast_top top down 2
path_ast_top_2 = './log/AsteroidsNoFrameskip-v4/a2c/ast_top_down_seed_2_2023-04-06-03-53/all_scalars.json'
with open(path_ast_top_2, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_ast_top_2, y_ast_top_2 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % size == 0 :
        y_ast_top_2.append(scores/size)
        x_ast_top_2.append(steps)
        scores = 0
    i += 1

# %%
# asteroids selftention 2
pselfh_ast_self_2 = '../baseline_log/log/AsteroidsNoFrameskip-v4/a2c/asteroids_self_seed_2_2023-04-03-03-10/all_scalars.json'
with open(pselfh_ast_self_2, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    dselfa1 = json.load(fp)
rec_x,rec_y = [], []
x_ast_self_2, y_ast_self_2 = [], []
i, scores = 1, 0
#print(dselfa1)
#_, infos = dselfa1.items()
dselfa = (list(dselfa1.values())[0])
for _, steps, score in dselfa:
    scores += score
    if i % 2 == 0 :
        y_ast_self_2.append(scores/2)
        x_ast_self_2.append(steps)
        scores = 0
    i += 1

# %%
#ast_multeway att 2
size = 4
path_ast_mult_2 = './log/AsteroidsNoFrameskip-v4/a2c/ast_multi_seed_2_2023-04-06-15-07/all_scalars.json'
with open(path_ast_mult_2, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_ast_mult_2, y_ast_mult_2 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % size == 0 :
        y_ast_mult_2.append(scores/size)
        x_ast_mult_2.append(steps)
        scores = 0

    i += 1

# %%
# astnival trans from pacman 
path_ast_trans_2 = './log/AsteroidsNoFrameskip-v4/a2c/ast_trans_seed_2_2023-04-07-23-23/all_scalars.json'
with open(path_ast_trans_2, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_ast_trans_2, y_ast_trans_2 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % 3 == 0 :
        y_ast_trans_2.append(scores/3)
        x_ast_trans_2.append(steps)
        scores = 0
    i += 1

# %%
x_ast_base, y_ast_base = x_ast_1, [(y_ast_1[i] + y_ast_2[i])/2 for i in range(len(y_ast_1))]
x_ast_top, y_ast_top = x_ast_top_1, [(y_ast_top_1[i] + y_ast_top_2[i])/2 for i in range(len(y_ast_top_1))]
plt.plot(x_ast_base, y_ast_base, label = "a2c")
plt.plot(x_ast_at_2, y_ast_at_2, label = "a2c w/ our attention")
plt.plot(x_ast_top, y_ast_top, label = "a2c w/ top-down attention")
#plt.plot(x_ast_self_2, y_ast_self_2, label = "a2c w/ self-attention")
#plt.plot(x_ast_mult_2, y_ast_mult_2, label = "a2c w/ univ.attention")
#plt.plot(x_ast_trans_2, y_ast_trans_2, label = "a2c w/ fix att. from Ms Pacman")
plt.xlabel('num of steps',fontsize=16)
plt.ylabel('test scores',fontsize=16)
plt.title('Asteroids',fontsize=16)
plt.legend(fontsize=12)
plt.show()

# %% [markdown]
# # Timepilot

# %%
#time baseline 1
path_time_1 = '../baseline_log/log/TimePilotNoFrameskip-v4/a2c/timepilot_seed_1_2023-04-03-11-29/all_scalars.json'
with open(path_time_1, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_time_1, y_time_1 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % 1 == 0 :
        y_time_1.append(scores/1)
        x_time_1.append(steps)
        scores = 0
    i += 1  
 #time baseline 2
path_time_2 = '../baseline_log/log/TimePilotNoFrameskip-v4/a2c/timepilot_seed_2_2023-04-03-08-38/all_scalars.json'
with open(path_time_2, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_time_2, y_time_2 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % 1 == 0 :
        y_time_2.append(scores/1)
        x_time_2.append(steps)
        scores = 0
    i += 1

# %%
#time att 1
size=4
path_time_at_1 = './log/TimePilotNoFrameskip-v4/a2c/timepilot_seed_1_2023-04-08-17-47/all_scalars.json'
with open(path_time_at_1, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_time_at_1, y_time_at_1 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % size == 0 :
        y_time_at_1.append(scores/size)
        x_time_at_1.append(steps)
        scores = 0
    i += 1 
    
    #time_ateway att 2
size=3
path_time_at_2 = './log/TimePilotNoFrameskip-v4/a2c/timepilot_seed_2_2023-04-07-22-53/all_scalars.json'
with open(path_time_at_2, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_time_at_2, y_time_at_2 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % size == 0 :
        y_time_at_2.append(scores/size)
        x_time_at_2.append(steps)
        scores = 0
    i += 1

# %%
#time_self baseline 1
path_time_self_1 = '../baseline_log/log/TimePilotNoFrameskip-v4/a2c/timepilot_self_seed_1_2023-04-03-11-29/all_scalars.json'
with open(path_time_self_1, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_time_self_1, y_time_self_1 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % 2 == 0 :
        y_time_self_1.append(scores/2)
        x_time_self_1.append(steps)
        scores = 0
    i += 1  
 #time_self baseline 2
path_time_self_2 = '../baseline_log/log/TimePilotNoFrameskip-v4/a2c/timepilot_self_seed_2_2023-04-03-08-38/all_scalars.json'
with open(path_time_self_2, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_time_self_2, y_time_self_2 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % 2 == 0 :
        y_time_self_2.append(scores/2)
        x_time_self_2.append(steps)
        scores = 0
    i += 1

# %%
/log/TimePilotNoFrameskip-v4/a2c/timepilot_seed_2_2023-04-07-22-53/all_scalars.json

# %%
size=4
# time top-down attention 1
path_time_top_1 = './log/TimePilotNoFrameskip-v4/a2c/time_top_seed_1_2023-04-07-22-52/all_scalars.json'
with open(path_time_top_1, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_time_top_1, y_time_top_1 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % size == 0 :
        y_time_top_1.append(scores/size)
        x_time_top_1.append(steps)
        scores = 0
    i += 1 
    #time_top top down 2
path_time_top_2 = './log/TimePilotNoFrameskip-v4/a2c/time_top_seed_2_2023-04-07-22-52/all_scalars.json'
with open(path_time_top_2, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_time_top_2, y_time_top_2 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % size == 0 :
        y_time_top_2.append(scores/size)
        x_time_top_2.append(steps)
        scores = 0
    i += 1 
# time top-down attention 3
path_time_top_3 = './log/TimePilotNoFrameskip-v4/a2c/time_top_seed_3_2023-04-08-23-30/all_scalars.json'
with open(path_time_top_3, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_time_top_3, y_time_top_3 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % size == 0 :
        y_time_top_3.append(scores/size)
        x_time_top_3.append(steps)
        scores = 0
    i += 1 
# time top-down attention 4
path_time_top_4 = './log/TimePilotNoFrameskip-v4/a2c/time_top_seed_4_2023-04-08-23-30/all_scalars.json'
with open(path_time_top_4, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_time_top_4, y_time_top_4 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % size == 0 :
        y_time_top_4.append(scores/size)
        x_time_top_4.append(steps)
        scores = 0
    i += 1
# time top-down attention 5
path_time_top_5 = './log/TimePilotNoFrameskip-v4/a2c/time_top_seed_5_2023-04-08-23-31/all_scalars.json'
with open(path_time_top_5, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_time_top_5, y_time_top_5 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % size == 0 :
        y_time_top_5.append(scores/size)
        x_time_top_5.append(steps)
        scores = 0
    i += 1

# %%
size=2
# time trans from carnival 
path_time_trans_1 = './log/TimePilotNoFrameskip-v4/a2c/time_from_car_seed_1_2023-04-08-18-22/all_scalars.json'
with open(path_time_trans_1, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_time_trans_1, y_time_trans_1 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % size == 0 :
        y_time_trans_1.append(scores/size)
        x_time_trans_1.append(steps)
        scores = 0
    i += 1 
# timenival trans from timeman 
path_time_trans_2 = './log/TimePilotNoFrameskip-v4/a2c/time_from_car_seed_2_2023-04-08-13-23/all_scalars.json'
with open(path_time_trans_2, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_time_trans_2, y_time_trans_2 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % size == 0 :
        y_time_trans_2.append(scores/size)
        x_time_trans_2.append(steps)
        scores = 0
    i += 1 
path_time_trans_3 = './log/TimePilotNoFrameskip-v4/a2c/time_from_car_seed_3_2023-04-08-18-22/all_scalars.json'
with open(path_time_trans_3, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_time_trans_3, y_time_trans_3 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % size == 0 :
        y_time_trans_3.append(scores/size)
        x_time_trans_3.append(steps)
        scores = 0
    i += 1

# %%
# time trans from car
path_time_trans_2 = './log/TimePilotNoFrameskip-v4/a2c/time_from_car_seed_2_2023-04-08-13-23/all_scalars.json'
with open(path_time_trans_2, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_time_trans_2, y_time_trans_2 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % 3 == 0 :
        y_time_trans_2.append(scores/3)
        x_time_trans_2.append(steps)
        scores = 0
    i += 1

# %%
/log/TimePilotNoFrameskip-v4/a2c/timepilot_seed_1_2023-04-08-17-47/all_scalars.json

# %%
x_time_base, y_time_base = x_time_1, [(y_time_1[i] + y_time_2[i])/2 for i in range(len(y_time_1))]
x_time_at, y_time_at = x_time_at_1, [(y_time_at_1[i] + y_time_at_2[i])/2 for i in range(len(y_time_at_1))]
x_time_top, y_time_top = x_time_top_1, [(y_time_top_1[i]
                                         + y_time_top_2[i]
                                         + y_time_top_3[i]
                                         + y_time_top_4[i] +  y_time_top_5[i])/5 for i in range(len(y_time_top_1))]
x_time_trans, y_time_trans = x_time_trans_1, [(y_time_trans_1[i] + y_time_trans_2[i] + 
                                         y_time_trans_3[i])/3 for i in range(len(y_time_trans_1))]
plt.plot(x_time_base, y_time_base, label = "a2c")
plt.plot(x_time_top, y_time_top, label = "a2c w/ our attention")
plt.plot(x_time_at, y_time_at, label = "a2c w/ top-down attention")
#plt.plot(x_time_self_2, y_time_self_2, label = "a2c w/ self-attention")
#plt.plot(x_time_trans, y_time_trans, label = "a2c w/ transattention")

plt.xlabel('num of steps',fontsize=16)
plt.ylabel('test scores',fontsize=16)
plt.title('TimePilot',fontsize=16)
plt.legend(fontsize=12)
plt.show()

# %% [markdown]
# # JourneyEscape

# %%
#jou baseline 1
path_jou_1 = '../Self-Sup-Attention-RL/log/JourneyEscapeNoFrameskip-v4/a2c/Jou_seed_1_2023-04-08-13-19/all_scalars.json'
with open(path_jou_1, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_jou_1, y_jou_1 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % 2 == 0 :
        y_jou_1.append(scores/2)
        x_jou_1.append(steps)
        scores = 0
    i += 1

# %%
/log/JourneyEscapeNoFrameskip-v4/a2c/jou_seed_2_2023-04-08-00-34/all_scalars.json

# %%
#jou_ateway att 2
size=2
path_jou_at_2 = './log/JourneyEscapeNoFrameskip-v4/a2c/jou_seed_2_2023-04-08-00-34/all_scalars.json'
with open(path_jou_at_2, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_jou_at_2, y_jou_at_2 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % size == 0 :
        y_jou_at_2.append(scores/size)
        x_jou_at_2.append(steps)
        scores = 0
    i += 1

# %%
#x_jou_base, y_jou_base = x_jou_1, [(y_jou_1[i] + y_jou_2[i])/2 for i in range(len(y_jou_1))]
#x_jou_top, y_jou_top = x_jou_top_1, [(y_jou_top_1[i] + y_jou_top_2[i])/2 for i in range(len(y_jou_top_1))]
plt.plot(x_jou_1, y_jou_1, label = "a2c")
plt.plot(x_jou_at_2, y_jou_at_2, label = "a2c w/our attention")
#plt.plot(x_jou_top, y_jou_top, label = "a2c w/ top-down attention")
#plt.plot(x_jou_self_2, y_jou_self_2, label = "a2c w/ self-attention")
plt.xlabel('num of steps')
plt.ylabel('test scores')
plt.title('jouPilot')
plt.legend()
plt.show()

# %% [markdown]
# # Skiing

# %%
/yangsy/baseline_log/log/SkiingNoFrameskip-v4/a2c/Skiing_seed_1_2023-04-03-11-30/all_scalars.json

# %%
/yangsy/baseline_log/log/SkiingNoFrameskip-v4/a2c/Skiing_seed_2_2023-04-03-08-34/all_scalars.json

# %%
size=4
#ski baseline 1
path_ski_1 = '../baseline_log/log/SkiingNoFrameskip-v4/a2c/Skiing_seed_1_2023-04-03-11-30/all_scalars.json'
with open(path_ski_1, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_ski_1, y_ski_1 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % size == 0 :
        y_ski_1.append(scores/size)
        x_ski_1.append(steps)
        scores = 0
    i += 1  
 #ski baseline 2
path_ski_2 = '../baseline_log/log/SkiingNoFrameskip-v4/a2c/Skiing_seed_2_2023-04-03-08-34/all_scalars.json'
with open(path_ski_2, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_ski_2, y_ski_2 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % size == 0 :
        y_ski_2.append(scores/size)
        x_ski_2.append(steps)
        scores = 0
    i += 1

# %%
/yangsy/DM-homework/log/SkiingNoFrameskip-v4/a2c/ski_top_down_seed_1_2023-04-08-18-35/all_scalars.json

# %%
size=2
# ski  self-attention 1
path_ski_self_1 = '../baseline_log/log/SkiingNoFrameskip-v4/a2c/Skiing_self_seed_1_2023-04-03-11-30/all_scalars.json'
with open(path_ski_self_1, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_ski_self_1, y_ski_self_1 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % size == 0 :
        y_ski_self_1.append(scores/size)
        x_ski_self_1.append(steps)
        scores = 0
    i += 1 
    #ski top down 2
path_ski_self_2 = '../baseline_log/log/SkiingNoFrameskip-v4/a2c/Skiing_self_seed_2_2023-04-03-08-34/all_scalars.json'
with open(path_ski_self_2, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_ski_self_2, y_ski_self_2 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % size == 0 :
        y_ski_self_2.append(scores/size)
        x_ski_self_2.append(steps)
        scores = 0
    i += 1

# %%
size=2
# ski top-down attention 1
path_ski_top_1 = './log/SkiingNoFrameskip-v4/a2c/ski_top_down_seed_1_2023-04-08-18-35/all_scalars.json'
with open(path_ski_top_1, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_ski_top_1, y_ski_top_1 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % size == 0 :
        y_ski_top_1.append(scores/size)
        x_ski_top_1.append(steps)
        scores = 0
    i += 1 
    #ski_top top down 2
path_ski_top_2 = './log/SkiingNoFrameskip-v4/a2c/ski_top_down_seed_2_2023-04-08-18-35/all_scalars.json'
with open(path_ski_top_2, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
rec_x,rec_y = [], []
x_ski_top_2, y_ski_top_2 = [], []
i, scores = 1, 0
#print(data1)
#_, infos = data1.items()
data = (list(data1.values())[0])
for _, steps, score in data:
    scores += score
    if i % size == 0 :
        y_ski_top_2.append(scores/size)
        x_ski_top_2.append(steps)
        scores = 0
    i += 1

# %%
/log/SkiingNoFrameskip-v4/a2c/ski_top_down_seed_2_2023-04-08-18-35/all_scalars.json

# %%
x_ski_base, y_ski_base = x_ski_1, [(y_ski_1[i] + y_ski_2[i])/2 for i in range(len(y_ski_1))]
x_ski_self, y_ski_self = x_ski_self_1, [(y_ski_self_1[i] + y_ski_self_2[i])/2 for i in range(len(y_ski_self_1))]
x_ski_top, y_ski_top = x_ski_top_1, [(y_ski_top_1[i] + y_ski_top_2[i])/2 for i in range(len(y_ski_top_1))]
plt.plot(x_ski_base, y_ski_base, label = "a2c")
#plt.plot(x_ski_at_2, y_ski_at_2, label = "a2c w/our attention")
plt.plot(x_ski_top, y_ski_top, label = "a2c w/ top-down attention")
plt.plot(x_ski_self, y_ski_self, label = "a2c w/ self-attention")
plt.xlabel('num of steps')
plt.ylabel('test scores')
plt.title('skiing')
plt.legend()
plt.show()

# %%
/log/JourneyEscapeNoFrameskip-v4/a2c/Jou_seed_1_2023-04-08-13-19/all_scalars.json

# %%
2 =1

# %%
aaa =1

# %%
#plt.plot(x1, y1, label = "test3")
#plt.plot(x6, y6, label = "test6")
plt.plot(x_pac_2, y_pac_2, label = "test6")
plt.plot(x_pac_base, y_pac_base, label = "test_mult")
#plt.plot(x5, y5, label = "test03")
plt.legend()
plt.show()

# %%
path03 = './test3/log/MsPacmanNoFrameskip-v4/a2c/e_seed_1_2023-03-31-17-14/all_scalars.json'
with open(path03, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
x03, y03 = [], []
for _, infos in data1.items():
    for _, steps, scores in infos:
        x03.append(steps)
        y03.append(scores)

# %%
path_mult = './log/MsPacmanNoFrameskip-v4/a2c/aug34256_seed_2_2023-04-05-03-34/all_scalars.json'
with open(path_mult, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
x_mult, y_mult = [], []
for _, infos in data1.items():
    for _, steps, scores in infos:
        x_mult.append(steps)
        y_mult.append(scores)

# %%
path11 = './log/MsPacmanNoFrameskip-v4/a2c/aug124256_seed_2_2023-04-05-03-36/all_scalars.json'
with open(path11, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
x_mult, y_mult = [], []
for _, infos in data1.items():
    for _, steps, scores in infos:
        x_mult.append(steps)
        y_mult.append(scores)

# %%
path22 = '../baseline_log/log/MsPacmanNoFrameskip-v4/a2c/a2c_mspacman_selfatt_thre1e-2_sparsity1e-3_seed_2_2023-04-03-03-08/all_scalars.json'
with open(path22, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
x_22, y_22 = [], []
for _, infos in data1.items():
    for _, steps, scores in infos:
        x_22.append(steps)
        y_22.append(scores)

# %%
#plt.plot(x1, y1, label = "test3")
#plt.plot(x6, y6, label = "test6")
plt.plot(x_22, y_22, label = "test6")
plt.plot(x_mult, y_mult, label = "test_mult")
#plt.plot(x5, y5, label = "test03")
plt.legend()
plt.show()

# %%
#carnival
path_c = './test3/log/MsPacmanNoFrameskip-v4/a2c/a2c_carnival_selfatt_thre1e-2_sparsity1e-3_seed_1_2023-03-31-15-34/all_scalars.json'
path_c_base = './Self-Sup-Attention-RL/log/CarnivalNoFrameskip-v4/a2c/a2c_mspacman_selfatt_thre1e-2_sparsity1e-3_seed_1_2023-03-31-15-41/all_scalars.json'
path_c_ba = './Self-Sup-Attention-RL/log/CarnivalNoFrameskip-v4/a2c/carnival_seed_1_2023-04-01-04-04/all_scalars.json'

# %%
with open(path_c_ba, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
x_c_ba, y_c_ba = [], []
for _, infos in data1.items():
    for _, steps, scores in infos:
        x_c_ba.append(steps)
        y_c_ba.append(scores)

# %%
with open(path_c, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
x_c, y_c = [], []
for _, infos in data1.items():
    for _, steps, scores in infos:
        x_c.append(steps)
        y_c.append(scores)

# %%
with open(path_c_base, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
x_cbase, y_cbase = [], []
for _, infos in data1.items():
    for _, steps, scores in infos:
        x_cbase.append(steps)
        y_cbase.append(scores)

# %%
plt.plot(x_c, y_c, label = "test3")
plt.plot(x_cbase, y_cbase, label = "test6")
plt.plot(x_c_ba, y_c_ba, label = "test5")
plt.legend()
plt.show()

# %%
path1 = './DM-homework/log/MsPacmanNoFrameskip-v4/a2c/run_1/all_scalars.json'
path2 = './test2/log/MsPacmanNoFrameskip-v4/a2c/run_1/all_scalars.json'
path3 = './test3/log/MsPacmanNoFrameskip-v4/a2c/run_2/all_scalars.json'
path4 = './test4/log/MsPacmanNoFrameskip-v4/a2c/run_1/all_scalars.json'
path5 = './baselines/self/all_scalars.json'
path6 = './baselines/endtoend/all_scalars.json'
path7 = './top-down/Self-Sup-Attention-RL/log/MsPacmanNoFrameskip-v4/a2c/run_1/all_scalars.json'
path8 = './multi-base/Self-Sup-Attention-RL/log/MsPacmanNoFrameskip-v4/a2c/run_1/all_scalars.json'

# %%
with open(path1, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data1 = json.load(fp)
x1, y1 = [], []
for _, infos in data1.items():
    for _, steps, scores in infos:
        x1.append(steps)
        y1.append(scores)

# %%
with open(path2, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data2 = json.load(fp)
x2, y2 = [], []
for _, infos in data2.items():
    for _, steps, scores in infos:
        x2.append(steps)
        y2.append(scores)

# %%
with open(path3, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data3 = json.load(fp)
x3, y3 = [], []
for _, infos in data3.items():
    for _, steps, scores in infos:
        x3.append(steps)
        y3.append(scores)

# %%
with open(path4, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data4 = json.load(fp)
x4, y4 = [], []
for _, infos in data4.items():
    for _, steps, scores in infos:
        x4.append(steps)
        y4.append(scores)

# %%
with open(path5, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data5 = json.load(fp)
x5, y5 = [], []
for _, infos in data5.items():
    for _, steps, scores in infos:
        x5.append(steps)
        y5.append(scores)

# %%
with open(path6, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data6 = json.load(fp)
x6, y6 = [], []
for _, infos in data6.items():
    for _, steps, scores in infos:
        x6.append(steps)
        y6.append(scores)

# %%
with open(path7, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data7 = json.load(fp)
x7, y7 = [], []
for _, infos in data7.items():
    for _, steps, scores in infos:
        x7.append(steps)
        y7.append(scores)

# %%
with open(path8, 'r',encoding = 'utf-8') as fp:
    # load()函数将fp(一个支持.read()的文件类对象，包含一个JSON文档)反序列化为一个Python对象
    data8 = json.load(fp)
x8, y8 = [], []
for _, infos in data8.items():
    for _, steps, scores in infos:
        x8.append(steps)
        y8.append(scores)

# %%
plt.xlabel('num of steps')
plt.ylabel('test_scores')
plt.plot(x1, y1, label = "test1")
#plt.plot(x2, y2, label = "test2")
plt.plot(x3, y3, label = "test3")
#plt.plot(x4, y4, label = "test4")
plt.legend()
plt.show()

# %%
plt.plot(x1, y1, label = "test1")
#plt.plot(x3, y3, label = "test3")
plt.plot(x6, y6, label = "test6")
plt.legend()
plt.show()
